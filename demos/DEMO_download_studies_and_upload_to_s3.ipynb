# %% [markdown]
# # DEMO: Studies download and upload to S3

# %% [markdown]
# [EN] This tutorial shows the steps to download data from a web page and upload them to the bucket.
#
# This document is divided by the following sections:
# 1. Data download
# 2. Data upload to the bucket
#
# [ES] Este tutorial muestra los pasos necesarios para descargar datos de una web y subirlos al bucket.
#
# Este documento está dividido en las siguiente secciones:
# 1. Descarga de los datos
# 2. Subida de los datos al bucket

# %% [markdown]
# ---
# ## 1 - Data download

# %% [markdown]
# [EN] 1. Follow this URL: https://clinicaltrials.gov/search?cond=Oncology
# 2. Select the data that you want to use for the RAG.
#
# ![image.png](attachment:6edc63f9-c3bb-42ec-9420-422ef647a503.png)
#
# 3. Press the download button.
#
# ![image.png](attachment:7b9649f3-084f-4864-9bc9-6103c8ed02b0.png)
#
# 4. Select CSV format and the desired fields.
#
# ![image.png](attachment:02623d1f-d0c1-4716-965f-856f34b2d789.png)
# ![image.png](attachment:3ee0cb1a-78a6-4cf7-9e84-27d916384261.png)
#
# 5. Click "Download" to download the data.
#
# [ES] 1. Acceda a la siguiente URL: https://clinicaltrials.gov/search?cond=Oncology
# 2. Seleccione los datos que desee utilizar para el RAG.
#
# ![image.png](attachment:6edc63f9-c3bb-42ec-9420-422ef647a503.png)
#
# 3. Pulse el botón de descarga.
#
# ![image.png](attachment:7b9649f3-084f-4864-9bc9-6103c8ed02b0.png)
#
# 4. Seleccione el formato CSV y los campos que prefieras.
#
# ![image.png](attachment:02623d1f-d0c1-4716-965f-856f34b2d789.png)
# ![image.png](attachment:3ee0cb1a-78a6-4cf7-9e84-27d916384261.png)
#
# 5. Haga clic en "Download" para descargar los datos.

# %% [markdown]
# ---
# ## 2. Data upload to a S3 bucket

# %% [markdown]
# [EN] You have been provided with a S3 bucket name that belongs to another account, but you vhave access to. **Change the following variable value to the bucket name.**.
#
# [ES] Se te habrá proporcionado el nombre de un bucket de S3 que pertenece a otra cuenta, pero al que tiene acceso. **Cambia el valor de la siguiente variable al nombre del bucket que se te ha proporcionado.**.

# %%
bucket_name = "shared-bucket-rag-test-jordi" # CHANGE THIS VALUE!

# %% [markdown]
# [EN] Run the following cell and access the bucket copying the generted URL or pressing the link.
#
# [ES] Ejecute la siguiente celda y acceda al bucket copiando la URL generado en su navegador o pulsando directamente el enlace.

# %%
from IPython.display import Markdown, display


full_bucket_url = f"https://us-west-2.console.aws.amazon.com/s3/buckets/{bucket_name}?region=us-west-2&bucketType=general&tab=objects"
display(Markdown(f"CTRL+CLICK to access the bucket: [{full_bucket_url}]({full_bucket_url})"))
# Out:
# CTRL+CLICK to access the bucket: [https://us-west-2.console.aws.amazon.com/s3/buckets/shared-bucket-rag-test-jordi?region=us-west-2&bucketType=general&tab=objects](https://us-west-2.console.aws.amazon.com/s3/buckets/shared-bucket-rag-test-jordi?region=us-west-2&bucketType=general&tab=objects)

# %% [markdown]
# [EN] After running the previous cell, you can access the bucket to upload the diles:
#
# [ES] Después de ejecutar la celda anterior, podrá acceder al bucket para subir los archivos:
#
# ![image.png](attachment:13b23153-45c4-459f-a43f-a67f5be90853.png)
#
# [EN] Click "Cargar" to upload the files:
#
# [ES] Haga clic en "Cargar" para subir los archivos:
#
# ![image.png](attachment:1d32aff9-ec04-4a5f-9d5c-c3241814e188.png)
#
# [EN] In the next screen, you can upload a folder if you have all of the filer grouped, just 1 file, or select different files one by one:
#
# [ES] En la siguiente pantalla, puede subir una carpeta si tienes todos los archivos agrupados, un solo archivo si es el caso, o también seleccionar varios archivos por separado:
#
# ![image.png](attachment:f6c7395f-ffe2-474b-b06b-1208c310791c.png)
#
# [EN] When all of the files are added, press "Cargar" to upload them to the S3 bucket.
#
# If everything was correct, you should see a confirmation like the following:
#
# [ES] Cuando haya añadido todos los archivos con los que desee trabajar, pulse el botón "Cargar" para subirlos al bucket de S3.
#
# Si todo ha ido bien, deberá ver una confirmación como esta al cabo de un rato:
#
# ![image.png](attachment:6dc2d903-47b5-4475-b145-7c0b0d3e2cb8.png)

# %% [markdown]
# [EN] Now you have the available data in S3. To create a RAG with this data you can follow the guide available in **demos** alled **RAG Knowledge Base**.
#
# [ES] Ahora ya tiene los datos disponibles en S3. Para crear un RAG con estos datos se recomienda seguir el manual disponible en **demos** llamado **RAG Knowledge Base**.
